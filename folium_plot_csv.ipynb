# %% [markdown]
# # Folium

# %%
import os
import pandas as pd 

fname = './data/DHO_cwv.gpx' #original gpx file
base, ext = os.path.splitext(fname)
read_filename="%s_combined.csv" % base

combo=pd.read_table(read_filename, header=0,sep=',',names=['time','lat','lon','rssi']);

# %%
# pip install folium
import folium

a=43.15733
b=-70.976616

#map_osm = folium.Map(location=[43.16050,-70.976616],zoom_start=15)
#map_osm = folium.Map(location=[43.16050,-70.976616],tiles='Stamen Terrain',zoom_start=15)
map_osm = folium.Map(location=[43.16050,-70.976616],tiles='MapQuestOpen Aerial',zoom_start=13)

kw = dict(opacity=1.0, weight=4)

for i in range(1,len(combo)):
    
    coordPrev=(combo.lat[i-1],combo.lon[i-1])
    coord=(combo.lat[i],combo.lon[i])
    loc=[coordPrev,coord]
    #signal strength 
    s=combo.rssi[i]
    c='green'
    if (s<-85):
        c='blue' 
    if (s<-95):
        c='yellow'
    if (s<-200):
        c='red'
    l = folium.PolyLine(locations=loc, color=c, **kw)
     
    map_osm.add_children(l)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
